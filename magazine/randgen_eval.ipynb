# %%
"""
    a test script for box-shape free generation
"""

import os
import sys
import shutil
import numpy as np
import torch
import utils
import vis_utils_layout as vis_utils
from data_layout import LayoutDataset, Tree
import model_layout as model

sys.setrecursionlimit(5000) # this code uses recursion a lot for code simplicity

# number of shapes to generate
num_gen = 1100

path = '/home/weiran/Code/Layout-CVPR22/1111_mag_contain_tanh/model'
data_path = '/home/weiran/Code/Layout-CVPR22/Data/mag_contain_1110_final/'
checkpoint = '307_'

# load train config
conf = torch.load(path + '/conf.pth')

# load object category information
Tree.load_category_info(conf.category)

# set up device
conf.device = 'cuda:0'
device = torch.device(conf.device)
print(f'Using device: {conf.device}')

# check if eval results already exist. If so, delete it. 
out_dir = '/home/weiran/Code/Layout-CVPR22/eval_output/magazine_new_tanh/freely_generated_shapes'
if os.path.exists(out_dir):
    # response = input('result directory %s exists, overwrite? (y/n) ' % out_dir)
    # if response != 'y':
    #     sys.exit()
    shutil.rmtree(out_dir)

# create a new directory to store eval results
os.mkdir(out_dir)

# create models
decoder = model.RecursiveDecoder(conf)

# load the pretrained models
print('Loading ckpt pretrained_decoder.pth')
data_to_restore = torch.load(path + '/' + checkpoint + 'net_decoder.pth')
decoder.load_state_dict(data_to_restore, strict=True)
print('DONE\n')

# send to device
decoder.to(device)

# set models to evaluation mode
decoder.eval()
# Out:
# Using device: cuda:0
# Loading ckpt pretrained_decoder.pth
# DONE
# RecursiveDecoder(
#   (box_decoder): BoxDecoder(
#     (xy): Linear(in_features=256, out_features=2, bias=True)
#     (size): Linear(in_features=256, out_features=2, bias=True)
#   )
#   (sem_decoder): SemDecoder(
#     (decoder): Linear(in_features=256, out_features=8, bias=True)
#   )
#   (leaf_decoder): LeafDecoder(
#     (decoder): Linear(in_features=256, out_features=256, bias=True)
#   )
#   (vertical_decoder): BranchDecoder(
#     (mlp_parent_1): Linear(in_features=256, out_features=1280, bias=True)
#     (mlp_parent_2): Linear(in_features=1280, out_features=1280, bias=True)
#     (mlp_exists): Linear(in_features=256, out_features=1, bias=True)
#     (mlp_arrange): Linear(in_features=256, out_features=20, bias=True)
#     (mlp_sem): Linear(in_features=256, out_features=8, bias=True)
#     (mlp_child): Linear(in_features=256, out_features=256, bias=True)
#   )
#   (horizontal_decoder): BranchDecoder(
#     (mlp_parent_1): Linear(in_features=256, out_features=1280, bias=True)
#     (mlp_parent_2): Linear(in_features=1280, out_features=1280, bias=True)
#     (mlp_exists): Linear(in_features=256, out_features=1, bias=True)
#     (mlp_arrange): Linear(in_features=256, out_features=20, bias=True)
#     (mlp_sem): Linear(in_features=256, out_features=8, bias=True)
#     (mlp_child): Linear(in_features=256, out_features=256, bias=True)
#   )
#   (stack_decoder): BranchDecoder(
#     (mlp_parent_1): Linear(in_features=256, out_features=1280, bias=True)
#     (mlp_parent_2): Linear(in_features=1280, out_features=1280, bias=True)
#     (mlp_exists): Linear(in_features=256, out_features=1, bias=True)
#     (mlp_arrange): Linear(in_features=256, out_features=20, bias=True)
#     (mlp_sem): Linear(in_features=256, out_features=8, bias=True)
#     (mlp_child): Linear(in_features=256, out_features=256, bias=True)
#   )
#   (sample_decoder): SampleDecoder(
#     (mlp1): Linear(in_features=256, out_features=256, bias=True)
#     (mlp2): Linear(in_features=256, out_features=256, bias=True)
#   )
#   (leaf_classifier): LeafClassifier(
#     (mlp1): Linear(in_features=256, out_features=256, bias=True)
#     (mlp2): Linear(in_features=256, out_features=4, bias=True)
#   )
#   (bceLoss): BCEWithLogitsLoss()
#   (semCELoss): CrossEntropyLoss()
#   (mseLoss): MSELoss()
# )

# %%
# generate shapes
with torch.no_grad():
    for i in range(num_gen):
        print(f'Generating {i}/{num_gen} ...')

        # get a Gaussian noise
        code = torch.randn(1, conf.feature_size).cuda()
        
        # infer through the model to get the generated hierarchy
        # set maximal tree depth to conf.max_tree_depth
        obj_arr = decoder.decode_structure(z=code, max_depth=conf.max_tree_depth)

        obj_arr.get_arrbox()
        
        # output the hierarchy
        with open(os.path.join(out_dir, 'gen-%03d.txt'%i), 'w') as fout:
            fout.write(str(obj_arr)+'\n\n')

        # output the assembled box-shape
        vis_utils.draw_partnet_objects([obj_arr],\
                object_names=['GENERATION'], \
                figsize=(5, 6), out_fn=os.path.join(out_dir, 'gen-%03d.jpg'%i),\
                leafs_only=True,sem_colors_filename='./part_colors_magazine.txt')
# Out:
# Generating 0/1100 ...
# Generating 1/1100 ...
# Generating 2/1100 ...
# Generating 3/1100 ...
# Generating 4/1100 ...
# Generating 5/1100 ...
# Generating 6/1100 ...
# Generating 7/1100 ...
# Generating 8/1100 ...
# Generating 9/1100 ...
# Generating 10/1100 ...
# Generating 11/1100 ...
# Generating 12/1100 ...
# Generating 13/1100 ...
# Generating 14/1100 ...
# Generating 15/1100 ...
# Generating 16/1100 ...
# Generating 17/1100 ...
# Generating 18/1100 ...
# Generating 19/1100 ...
# Generating 20/1100 ...
# Generating 21/1100 ...
# Generating 22/1100 ...
# Generating 23/1100 ...
# Generating 24/1100 ...
# Generating 25/1100 ...
# Generating 26/1100 ...
# Generating 27/1100 ...
# Generating 28/1100 ...
# Generating 29/1100 ...
# Generating 30/1100 ...
# Generating 31/1100 ...
# Generating 32/1100 ...
# Generating 33/1100 ...
# Generating 34/1100 ...
# Generating 35/1100 ...
# Generating 36/1100 ...
# Generating 37/1100 ...
# Generating 38/1100 ...
# Generating 39/1100 ...
# Generating 40/1100 ...
# Generating 41/1100 ...
# Generating 42/1100 ...
# Generating 43/1100 ...
# Generating 44/1100 ...
# Generating 45/1100 ...
# Generating 46/1100 ...
# Generating 47/1100 ...
# Generating 48/1100 ...
# Generating 49/1100 ...
# Generating 50/1100 ...
# Generating 51/1100 ...
# Generating 52/1100 ...
# Generating 53/1100 ...
# Generating 54/1100 ...
# Generating 55/1100 ...
# Generating 56/1100 ...
# Generating 57/1100 ...
# Generating 58/1100 ...
# Generating 59/1100 ...
# Generating 60/1100 ...
# Generating 61/1100 ...
# Generating 62/1100 ...
# Generating 63/1100 ...
# Generating 64/1100 ...
# Generating 65/1100 ...
# Generating 66/1100 ...
# Generating 67/1100 ...
# Generating 68/1100 ...
# Generating 69/1100 ...
# Generating 70/1100 ...
# Generating 71/1100 ...
# Generating 72/1100 ...
# Generating 73/1100 ...
# Generating 74/1100 ...
# Generating 75/1100 ...
# Generating 76/1100 ...
# Generating 77/1100 ...
# Generating 78/1100 ...
# Generating 79/1100 ...
# Generating 80/1100 ...
# Generating 81/1100 ...
# Generating 82/1100 ...
# Generating 83/1100 ...
# Generating 84/1100 ...
# Generating 85/1100 ...
# Generating 86/1100 ...
# Generating 87/1100 ...
# Generating 88/1100 ...
# Generating 89/1100 ...
# Generating 90/1100 ...
# Generating 91/1100 ...
# Generating 92/1100 ...
# Generating 93/1100 ...
# Generating 94/1100 ...
# Generating 95/1100 ...
# Generating 96/1100 ...
# Generating 97/1100 ...
# Generating 98/1100 ...
# Generating 99/1100 ...
# Generating 100/1100 ...
# Generating 101/1100 ...
# Generating 102/1100 ...
# Generating 103/1100 ...
# Generating 104/1100 ...
# Generating 105/1100 ...
# Generating 106/1100 ...
# Generating 107/1100 ...
# Generating 108/1100 ...
# Generating 109/1100 ...
# Generating 110/1100 ...
# Generating 111/1100 ...
# Generating 112/1100 ...
# Generating 113/1100 ...
# Generating 114/1100 ...
# Generating 115/1100 ...
# Generating 116/1100 ...
# Generating 117/1100 ...
# Generating 118/1100 ...
# Generating 119/1100 ...
# Generating 120/1100 ...
# Generating 121/1100 ...
# Generating 122/1100 ...
# Generating 123/1100 ...
# Generating 124/1100 ...
# Generating 125/1100 ...
# Generating 126/1100 ...
# Generating 127/1100 ...
# Generating 128/1100 ...
# Generating 129/1100 ...
# Generating 130/1100 ...
# Generating 131/1100 ...
# Generating 132/1100 ...
# Generating 133/1100 ...
# Generating 134/1100 ...
# Generating 135/1100 ...
# Generating 136/1100 ...
# Generating 137/1100 ...
# Generating 138/1100 ...
# Generating 139/1100 ...
# Generating 140/1100 ...
# Generating 141/1100 ...
# Generating 142/1100 ...
# Generating 143/1100 ...
# Generating 144/1100 ...
# Generating 145/1100 ...
# Generating 146/1100 ...
# Generating 147/1100 ...
# Generating 148/1100 ...
# Generating 149/1100 ...
# Generating 150/1100 ...
# Generating 151/1100 ...
# Generating 152/1100 ...
# Generating 153/1100 ...
# Generating 154/1100 ...
# Generating 155/1100 ...
# Generating 156/1100 ...
# Generating 157/1100 ...
# Generating 158/1100 ...
# Generating 159/1100 ...
# Generating 160/1100 ...
# Generating 161/1100 ...
# Generating 162/1100 ...
# Generating 163/1100 ...
# Generating 164/1100 ...
# Generating 165/1100 ...
# Generating 166/1100 ...
# Generating 167/1100 ...
# Generating 168/1100 ...
# Generating 169/1100 ...
# Generating 170/1100 ...
# Generating 171/1100 ...
# Generating 172/1100 ...
# Generating 173/1100 ...
# Generating 174/1100 ...
# Generating 175/1100 ...
# Generating 176/1100 ...
# Generating 177/1100 ...
# Generating 178/1100 ...
# Generating 179/1100 ...
# Generating 180/1100 ...
# Generating 181/1100 ...
# Generating 182/1100 ...
# Generating 183/1100 ...
# Generating 184/1100 ...
# Generating 185/1100 ...
# Generating 186/1100 ...
# Generating 187/1100 ...
# Generating 188/1100 ...
# Generating 189/1100 ...
# Generating 190/1100 ...
# Generating 191/1100 ...
# Generating 192/1100 ...
# Generating 193/1100 ...
# Generating 194/1100 ...
# Generating 195/1100 ...
# Generating 196/1100 ...
# Generating 197/1100 ...
# Generating 198/1100 ...
# Generating 199/1100 ...
# Generating 200/1100 ...
# Generating 201/1100 ...
# Generating 202/1100 ...
# Generating 203/1100 ...
# Generating 204/1100 ...
# Generating 205/1100 ...
# Generating 206/1100 ...
# Generating 207/1100 ...
# Generating 208/1100 ...
# Generating 209/1100 ...
# Generating 210/1100 ...
# Generating 211/1100 ...
# Generating 212/1100 ...
# Generating 213/1100 ...
# Generating 214/1100 ...
# Generating 215/1100 ...
# Generating 216/1100 ...
# Generating 217/1100 ...
# Generating 218/1100 ...
# Generating 219/1100 ...
# Generating 220/1100 ...
# Generating 221/1100 ...
# Generating 222/1100 ...
# Generating 223/1100 ...
# Generating 224/1100 ...
# Generating 225/1100 ...
# Generating 226/1100 ...
# Generating 227/1100 ...
# Generating 228/1100 ...
# Generating 229/1100 ...
# Generating 230/1100 ...
# Generating 231/1100 ...
# Generating 232/1100 ...
# Generating 233/1100 ...
# Generating 234/1100 ...
# Generating 235/1100 ...
# Generating 236/1100 ...
# Generating 237/1100 ...
# Generating 238/1100 ...
# Generating 239/1100 ...
# Generating 240/1100 ...
# Generating 241/1100 ...
# Generating 242/1100 ...
# Generating 243/1100 ...
# Generating 244/1100 ...
# Generating 245/1100 ...
# Generating 246/1100 ...
# Generating 247/1100 ...
# Generating 248/1100 ...
# Generating 249/1100 ...
# Generating 250/1100 ...
# Generating 251/1100 ...
# Generating 252/1100 ...
# Generating 253/1100 ...
# Generating 254/1100 ...
# Generating 255/1100 ...
# Generating 256/1100 ...
# Generating 257/1100 ...
# Generating 258/1100 ...
# Generating 259/1100 ...
# Generating 260/1100 ...
# Generating 261/1100 ...
# Generating 262/1100 ...
# Generating 263/1100 ...
# Generating 264/1100 ...
# Generating 265/1100 ...
# Generating 266/1100 ...
# Generating 267/1100 ...
# Generating 268/1100 ...
# Generating 269/1100 ...
# Generating 270/1100 ...
# Generating 271/1100 ...
# Generating 272/1100 ...
# Generating 273/1100 ...
# Generating 274/1100 ...
# Generating 275/1100 ...
# Generating 276/1100 ...
# Generating 277/1100 ...
# Generating 278/1100 ...
# Generating 279/1100 ...
# Generating 280/1100 ...
# Generating 281/1100 ...
# Generating 282/1100 ...
# Generating 283/1100 ...
# Generating 284/1100 ...
# Generating 285/1100 ...
# Generating 286/1100 ...
# Generating 287/1100 ...
# Generating 288/1100 ...
# Generating 289/1100 ...
# Generating 290/1100 ...
# Generating 291/1100 ...
# Generating 292/1100 ...
# Generating 293/1100 ...
# Generating 294/1100 ...
# Generating 295/1100 ...
# Generating 296/1100 ...
# Generating 297/1100 ...
# Generating 298/1100 ...
# Generating 299/1100 ...
# Generating 300/1100 ...
# Generating 301/1100 ...
# Generating 302/1100 ...
# Generating 303/1100 ...
# Generating 304/1100 ...
# Generating 305/1100 ...
# Generating 306/1100 ...
# Generating 307/1100 ...
# Generating 308/1100 ...
# Generating 309/1100 ...
# Generating 310/1100 ...
# Generating 311/1100 ...
# Generating 312/1100 ...
# Generating 313/1100 ...
# Generating 314/1100 ...
# Generating 315/1100 ...
# Generating 316/1100 ...
# Generating 317/1100 ...
# Generating 318/1100 ...
# Generating 319/1100 ...
# Generating 320/1100 ...
# Generating 321/1100 ...
# Generating 322/1100 ...
# Generating 323/1100 ...
# Generating 324/1100 ...
# Generating 325/1100 ...
# Generating 326/1100 ...
# Generating 327/1100 ...
# Generating 328/1100 ...
# Generating 329/1100 ...
# Generating 330/1100 ...
# Generating 331/1100 ...
# Generating 332/1100 ...
# Generating 333/1100 ...
# Generating 334/1100 ...
# Generating 335/1100 ...
# Generating 336/1100 ...
# Generating 337/1100 ...
# Generating 338/1100 ...
# Generating 339/1100 ...
# Generating 340/1100 ...
# Generating 341/1100 ...
# Generating 342/1100 ...
# Generating 343/1100 ...
# Generating 344/1100 ...
# Generating 345/1100 ...
# Generating 346/1100 ...
# Generating 347/1100 ...
# Generating 348/1100 ...
# Generating 349/1100 ...
# Generating 350/1100 ...
# Generating 351/1100 ...
# Generating 352/1100 ...
# Generating 353/1100 ...
# Generating 354/1100 ...
# Generating 355/1100 ...
# Generating 356/1100 ...
# Generating 357/1100 ...
# Generating 358/1100 ...
# Generating 359/1100 ...
# Generating 360/1100 ...
# Generating 361/1100 ...
# Generating 362/1100 ...
# Generating 363/1100 ...
# Generating 364/1100 ...
# Generating 365/1100 ...
# Generating 366/1100 ...
# Generating 367/1100 ...
# Generating 368/1100 ...
# Generating 369/1100 ...
# Generating 370/1100 ...
# Generating 371/1100 ...
# Generating 372/1100 ...
# Generating 373/1100 ...
# Generating 374/1100 ...
# Generating 375/1100 ...
# Generating 376/1100 ...
# Generating 377/1100 ...
# Generating 378/1100 ...
# Generating 379/1100 ...
# Generating 380/1100 ...
# Generating 381/1100 ...
# Generating 382/1100 ...
# Generating 383/1100 ...
# Generating 384/1100 ...
# Generating 385/1100 ...
# Generating 386/1100 ...
# Generating 387/1100 ...
# Generating 388/1100 ...
# Generating 389/1100 ...
# Generating 390/1100 ...
# Generating 391/1100 ...
# Generating 392/1100 ...
# Generating 393/1100 ...
# Generating 394/1100 ...
# Generating 395/1100 ...
# Generating 396/1100 ...
# Generating 397/1100 ...
# Generating 398/1100 ...
# Generating 399/1100 ...
# Generating 400/1100 ...
# Generating 401/1100 ...
# Generating 402/1100 ...
# Generating 403/1100 ...
# Generating 404/1100 ...
# Generating 405/1100 ...
# Generating 406/1100 ...
# Generating 407/1100 ...
# Generating 408/1100 ...
# Generating 409/1100 ...
# Generating 410/1100 ...
# Generating 411/1100 ...
# Generating 412/1100 ...
# Generating 413/1100 ...
# Generating 414/1100 ...
# Generating 415/1100 ...
# Generating 416/1100 ...
# Generating 417/1100 ...
# Generating 418/1100 ...
# Generating 419/1100 ...
# Generating 420/1100 ...
# Generating 421/1100 ...
# Generating 422/1100 ...
# Generating 423/1100 ...
# Generating 424/1100 ...
# Generating 425/1100 ...
# Generating 426/1100 ...
# Generating 427/1100 ...
# Generating 428/1100 ...
# Generating 429/1100 ...
# Generating 430/1100 ...
# Generating 431/1100 ...
# Generating 432/1100 ...
# Generating 433/1100 ...
# Generating 434/1100 ...
# Generating 435/1100 ...
# Generating 436/1100 ...
# Generating 437/1100 ...
# Generating 438/1100 ...
# Generating 439/1100 ...
# Generating 440/1100 ...
# Generating 441/1100 ...
# Generating 442/1100 ...
# Generating 443/1100 ...
# Generating 444/1100 ...
# Generating 445/1100 ...
# Generating 446/1100 ...
# Generating 447/1100 ...
# Generating 448/1100 ...
# Generating 449/1100 ...
# Generating 450/1100 ...
# Generating 451/1100 ...
# Generating 452/1100 ...
# Generating 453/1100 ...
# Generating 454/1100 ...
# Generating 455/1100 ...
# Generating 456/1100 ...
# Generating 457/1100 ...
# Generating 458/1100 ...
# Generating 459/1100 ...
# Generating 460/1100 ...
# Generating 461/1100 ...
# Generating 462/1100 ...
# Generating 463/1100 ...
# Generating 464/1100 ...
# Generating 465/1100 ...
# Generating 466/1100 ...
# Generating 467/1100 ...
# Generating 468/1100 ...
# Generating 469/1100 ...
# Generating 470/1100 ...
# Generating 471/1100 ...
# Generating 472/1100 ...
# Generating 473/1100 ...
# Generating 474/1100 ...
# Generating 475/1100 ...
# Generating 476/1100 ...
# Generating 477/1100 ...
# Generating 478/1100 ...
# Generating 479/1100 ...
# Generating 480/1100 ...
# Generating 481/1100 ...
# Generating 482/1100 ...
# Generating 483/1100 ...
# Generating 484/1100 ...
# Generating 485/1100 ...
# Generating 486/1100 ...
# Generating 487/1100 ...
# Generating 488/1100 ...
# Generating 489/1100 ...
# Generating 490/1100 ...
# Generating 491/1100 ...
# Generating 492/1100 ...
# Generating 493/1100 ...
# Generating 494/1100 ...
# Generating 495/1100 ...
# Generating 496/1100 ...
# Generating 497/1100 ...
# Generating 498/1100 ...
# Generating 499/1100 ...
# Generating 500/1100 ...
# Generating 501/1100 ...
# Generating 502/1100 ...
# Generating 503/1100 ...
# Generating 504/1100 ...
# Generating 505/1100 ...
# Generating 506/1100 ...
# Generating 507/1100 ...
# Generating 508/1100 ...
# Generating 509/1100 ...
# Generating 510/1100 ...
# Generating 511/1100 ...
# Generating 512/1100 ...
# Generating 513/1100 ...
# Generating 514/1100 ...
# Generating 515/1100 ...
# Generating 516/1100 ...
# Generating 517/1100 ...
# Generating 518/1100 ...
# Generating 519/1100 ...
# Generating 520/1100 ...
# Generating 521/1100 ...
# Generating 522/1100 ...
# Generating 523/1100 ...
# Generating 524/1100 ...
# Generating 525/1100 ...
# Generating 526/1100 ...
# Generating 527/1100 ...
# Generating 528/1100 ...
# Generating 529/1100 ...
# Generating 530/1100 ...
# Generating 531/1100 ...
# Generating 532/1100 ...
# Generating 533/1100 ...
# Generating 534/1100 ...
# Generating 535/1100 ...
# Generating 536/1100 ...
# Generating 537/1100 ...
# Generating 538/1100 ...
# Generating 539/1100 ...
# Generating 540/1100 ...
# Generating 541/1100 ...
# Generating 542/1100 ...
# Generating 543/1100 ...
# Generating 544/1100 ...
# Generating 545/1100 ...
# Generating 546/1100 ...
# Generating 547/1100 ...
# Generating 548/1100 ...
# Generating 549/1100 ...
# Generating 550/1100 ...
# Generating 551/1100 ...
# Generating 552/1100 ...
# Generating 553/1100 ...
# Generating 554/1100 ...
# Generating 555/1100 ...
# Generating 556/1100 ...
# Generating 557/1100 ...
# Generating 558/1100 ...
# Generating 559/1100 ...
# Generating 560/1100 ...
# Generating 561/1100 ...
# Generating 562/1100 ...
# Generating 563/1100 ...
# Generating 564/1100 ...
# Generating 565/1100 ...
# Generating 566/1100 ...
# Generating 567/1100 ...
# Generating 568/1100 ...
# Generating 569/1100 ...
# Generating 570/1100 ...
# Generating 571/1100 ...
# Generating 572/1100 ...
# Generating 573/1100 ...
# Generating 574/1100 ...
# Generating 575/1100 ...
# Generating 576/1100 ...
# Generating 577/1100 ...
# Generating 578/1100 ...
# Generating 579/1100 ...
# Generating 580/1100 ...
# Generating 581/1100 ...
# Generating 582/1100 ...
# Generating 583/1100 ...
# Generating 584/1100 ...
# Generating 585/1100 ...
# Generating 586/1100 ...
# Generating 587/1100 ...
# Generating 588/1100 ...
# Generating 589/1100 ...
# Generating 590/1100 ...
# Generating 591/1100 ...
# Generating 592/1100 ...
# Generating 593/1100 ...
# Generating 594/1100 ...
# Generating 595/1100 ...
# Generating 596/1100 ...
# Generating 597/1100 ...
# Generating 598/1100 ...
# Generating 599/1100 ...
# Generating 600/1100 ...
# Generating 601/1100 ...
# Generating 602/1100 ...
# Generating 603/1100 ...
# Generating 604/1100 ...
# Generating 605/1100 ...
# Generating 606/1100 ...
# Generating 607/1100 ...
# Generating 608/1100 ...
# Generating 609/1100 ...
# Generating 610/1100 ...
# Generating 611/1100 ...
# Generating 612/1100 ...
# Generating 613/1100 ...
# Generating 614/1100 ...
# Generating 615/1100 ...
# Generating 616/1100 ...
# Generating 617/1100 ...
# Generating 618/1100 ...
# Generating 619/1100 ...
# Generating 620/1100 ...
# Generating 621/1100 ...
# Generating 622/1100 ...
# Generating 623/1100 ...
# Generating 624/1100 ...
# Generating 625/1100 ...
# Generating 626/1100 ...
# Generating 627/1100 ...
# Generating 628/1100 ...
# Generating 629/1100 ...
# Generating 630/1100 ...
# Generating 631/1100 ...
# Generating 632/1100 ...
# Generating 633/1100 ...
# Generating 634/1100 ...
# Generating 635/1100 ...
# Generating 636/1100 ...
# Generating 637/1100 ...
# Generating 638/1100 ...
# Generating 639/1100 ...
# Generating 640/1100 ...
# Generating 641/1100 ...
# Generating 642/1100 ...
# Generating 643/1100 ...
# Generating 644/1100 ...
# Generating 645/1100 ...
# Generating 646/1100 ...
# Generating 647/1100 ...
# Generating 648/1100 ...
# Generating 649/1100 ...
# Generating 650/1100 ...
# Generating 651/1100 ...
# Generating 652/1100 ...
# Generating 653/1100 ...
# Generating 654/1100 ...
# Generating 655/1100 ...
# Generating 656/1100 ...
# Generating 657/1100 ...
# Generating 658/1100 ...
# Generating 659/1100 ...
# Generating 660/1100 ...
# Generating 661/1100 ...
# Generating 662/1100 ...
# Generating 663/1100 ...
# Generating 664/1100 ...
# Generating 665/1100 ...
# Generating 666/1100 ...
# Generating 667/1100 ...
# Generating 668/1100 ...
# Generating 669/1100 ...
# Generating 670/1100 ...
# Generating 671/1100 ...
# Generating 672/1100 ...
# Generating 673/1100 ...
# Generating 674/1100 ...
# Generating 675/1100 ...
# Generating 676/1100 ...
# Generating 677/1100 ...
# Generating 678/1100 ...
# Generating 679/1100 ...
# Generating 680/1100 ...
# Generating 681/1100 ...
# Generating 682/1100 ...
# Generating 683/1100 ...
# Generating 684/1100 ...
# Generating 685/1100 ...
# Generating 686/1100 ...
# Generating 687/1100 ...
# Generating 688/1100 ...
# Generating 689/1100 ...
# Generating 690/1100 ...
# Generating 691/1100 ...
# Generating 692/1100 ...
# Generating 693/1100 ...
# Generating 694/1100 ...
# Generating 695/1100 ...
# Generating 696/1100 ...
# Generating 697/1100 ...
# Generating 698/1100 ...
# Generating 699/1100 ...
# Generating 700/1100 ...
# Generating 701/1100 ...
# Generating 702/1100 ...
# Generating 703/1100 ...
# Generating 704/1100 ...
# Generating 705/1100 ...
# Generating 706/1100 ...
# Generating 707/1100 ...
# Generating 708/1100 ...
# Generating 709/1100 ...
# Generating 710/1100 ...
# Generating 711/1100 ...
# Generating 712/1100 ...
# Generating 713/1100 ...
# Generating 714/1100 ...
# Generating 715/1100 ...
# Generating 716/1100 ...
# Generating 717/1100 ...
# Generating 718/1100 ...
# Generating 719/1100 ...
# Generating 720/1100 ...
# Generating 721/1100 ...
# Generating 722/1100 ...
# Generating 723/1100 ...
# Generating 724/1100 ...
# Generating 725/1100 ...
# Generating 726/1100 ...
# Generating 727/1100 ...
# Generating 728/1100 ...
# Generating 729/1100 ...
# Generating 730/1100 ...
# Generating 731/1100 ...
# Generating 732/1100 ...
# Generating 733/1100 ...
# Generating 734/1100 ...
# Generating 735/1100 ...
# Generating 736/1100 ...
# Generating 737/1100 ...
# Generating 738/1100 ...
# Generating 739/1100 ...
# Generating 740/1100 ...
# Generating 741/1100 ...
# Generating 742/1100 ...
# Generating 743/1100 ...
# Generating 744/1100 ...
# Generating 745/1100 ...
# Generating 746/1100 ...
# Generating 747/1100 ...
# Generating 748/1100 ...
# Generating 749/1100 ...
# Generating 750/1100 ...
# Generating 751/1100 ...
# Generating 752/1100 ...
# Generating 753/1100 ...
# Generating 754/1100 ...
# Generating 755/1100 ...
# Generating 756/1100 ...
# Generating 757/1100 ...
# Generating 758/1100 ...
# Generating 759/1100 ...
# Generating 760/1100 ...
# Generating 761/1100 ...
# Generating 762/1100 ...
# Generating 763/1100 ...
# Generating 764/1100 ...
# Generating 765/1100 ...
# Generating 766/1100 ...
# Generating 767/1100 ...
# Generating 768/1100 ...
# Generating 769/1100 ...
# Generating 770/1100 ...
# Generating 771/1100 ...
# Generating 772/1100 ...
# Generating 773/1100 ...
# Generating 774/1100 ...
# Generating 775/1100 ...
# Generating 776/1100 ...
# Generating 777/1100 ...
# Generating 778/1100 ...
# Generating 779/1100 ...
# Generating 780/1100 ...
# Generating 781/1100 ...
# Generating 782/1100 ...
# Generating 783/1100 ...
# Generating 784/1100 ...
# Generating 785/1100 ...
# Generating 786/1100 ...
# Generating 787/1100 ...
# Generating 788/1100 ...
# Generating 789/1100 ...
# Generating 790/1100 ...
# Generating 791/1100 ...
# Generating 792/1100 ...
# Generating 793/1100 ...
# Generating 794/1100 ...
# Generating 795/1100 ...
# Generating 796/1100 ...
# Generating 797/1100 ...
# Generating 798/1100 ...
# Generating 799/1100 ...
# Generating 800/1100 ...
# Generating 801/1100 ...
# Generating 802/1100 ...
# Generating 803/1100 ...
# Generating 804/1100 ...
# Generating 805/1100 ...
# Generating 806/1100 ...
# Generating 807/1100 ...
# Generating 808/1100 ...
# Generating 809/1100 ...
# Generating 810/1100 ...
# Generating 811/1100 ...
# Generating 812/1100 ...
# Generating 813/1100 ...
# Generating 814/1100 ...
# Generating 815/1100 ...
# Generating 816/1100 ...
# Generating 817/1100 ...
# Generating 818/1100 ...
# Generating 819/1100 ...
# Generating 820/1100 ...
# Generating 821/1100 ...
# Generating 822/1100 ...
# Generating 823/1100 ...
# Generating 824/1100 ...
# Generating 825/1100 ...
# Generating 826/1100 ...
# Generating 827/1100 ...
# Generating 828/1100 ...
# Generating 829/1100 ...
# Generating 830/1100 ...
# Generating 831/1100 ...
# Generating 832/1100 ...
# Generating 833/1100 ...
# Generating 834/1100 ...
# Generating 835/1100 ...
# Generating 836/1100 ...
# Generating 837/1100 ...
# Generating 838/1100 ...
# Generating 839/1100 ...
# Generating 840/1100 ...
# Generating 841/1100 ...
# Generating 842/1100 ...
# Generating 843/1100 ...
# Generating 844/1100 ...
# Generating 845/1100 ...
# Generating 846/1100 ...
# Generating 847/1100 ...
# Generating 848/1100 ...
# Generating 849/1100 ...
# Generating 850/1100 ...
# Generating 851/1100 ...
# Generating 852/1100 ...
# Generating 853/1100 ...
# Generating 854/1100 ...
# Generating 855/1100 ...
# Generating 856/1100 ...
# Generating 857/1100 ...
# Generating 858/1100 ...
# Generating 859/1100 ...
# Generating 860/1100 ...
# Generating 861/1100 ...
# Generating 862/1100 ...
# Generating 863/1100 ...
# Generating 864/1100 ...
# Generating 865/1100 ...
# Generating 866/1100 ...
# Generating 867/1100 ...
# Generating 868/1100 ...
# Generating 869/1100 ...
# Generating 870/1100 ...
# Generating 871/1100 ...
# Generating 872/1100 ...
# Generating 873/1100 ...
# Generating 874/1100 ...
# Generating 875/1100 ...
# Generating 876/1100 ...
# Generating 877/1100 ...
# Generating 878/1100 ...
# Generating 879/1100 ...
# Generating 880/1100 ...
# Generating 881/1100 ...
# Generating 882/1100 ...
# Generating 883/1100 ...
# Generating 884/1100 ...
# Generating 885/1100 ...
# Generating 886/1100 ...
# Generating 887/1100 ...
# Generating 888/1100 ...
# Generating 889/1100 ...
# Generating 890/1100 ...
# Generating 891/1100 ...
# Generating 892/1100 ...
# Generating 893/1100 ...
# Generating 894/1100 ...
# Generating 895/1100 ...
# Generating 896/1100 ...
# Generating 897/1100 ...
# Generating 898/1100 ...
# Generating 899/1100 ...
# Generating 900/1100 ...
# Generating 901/1100 ...
# Generating 902/1100 ...
# Generating 903/1100 ...
# Generating 904/1100 ...
# Generating 905/1100 ...
# Generating 906/1100 ...
# Generating 907/1100 ...
# Generating 908/1100 ...
# Generating 909/1100 ...
# Generating 910/1100 ...
# Generating 911/1100 ...
# Generating 912/1100 ...
# Generating 913/1100 ...
# Generating 914/1100 ...
# Generating 915/1100 ...
# Generating 916/1100 ...
# Generating 917/1100 ...
# Generating 918/1100 ...
# Generating 919/1100 ...
# Generating 920/1100 ...
# Generating 921/1100 ...
# Generating 922/1100 ...
# Generating 923/1100 ...
# Generating 924/1100 ...
# Generating 925/1100 ...
# Generating 926/1100 ...
# Generating 927/1100 ...
# Generating 928/1100 ...
# Generating 929/1100 ...
# Generating 930/1100 ...
# Generating 931/1100 ...
# Generating 932/1100 ...
# Generating 933/1100 ...
# Generating 934/1100 ...
# Generating 935/1100 ...
# Generating 936/1100 ...
# Generating 937/1100 ...
# Generating 938/1100 ...
# Generating 939/1100 ...
# Generating 940/1100 ...
# Generating 941/1100 ...
# Generating 942/1100 ...
# Generating 943/1100 ...
# Generating 944/1100 ...
# Generating 945/1100 ...
# Generating 946/1100 ...
# Generating 947/1100 ...
# Generating 948/1100 ...
# Generating 949/1100 ...
# Generating 950/1100 ...
# Generating 951/1100 ...
# Generating 952/1100 ...
# Generating 953/1100 ...
# Generating 954/1100 ...
# Generating 955/1100 ...
# Generating 956/1100 ...
# Generating 957/1100 ...
# Generating 958/1100 ...
# Generating 959/1100 ...
# Generating 960/1100 ...
# Generating 961/1100 ...
# Generating 962/1100 ...
# Generating 963/1100 ...
# Generating 964/1100 ...
# Generating 965/1100 ...
# Generating 966/1100 ...
# Generating 967/1100 ...
# Generating 968/1100 ...
# Generating 969/1100 ...
# Generating 970/1100 ...
# Generating 971/1100 ...
# Generating 972/1100 ...
# Generating 973/1100 ...
# Generating 974/1100 ...
# Generating 975/1100 ...
# Generating 976/1100 ...
# Generating 977/1100 ...
# Generating 978/1100 ...
# Generating 979/1100 ...
# Generating 980/1100 ...
# Generating 981/1100 ...
# Generating 982/1100 ...
# Generating 983/1100 ...
# Generating 984/1100 ...
# Generating 985/1100 ...
# Generating 986/1100 ...
# Generating 987/1100 ...
# Generating 988/1100 ...
# Generating 989/1100 ...
# Generating 990/1100 ...
# Generating 991/1100 ...
# Generating 992/1100 ...
# Generating 993/1100 ...
# Generating 994/1100 ...
# Generating 995/1100 ...
# Generating 996/1100 ...
# Generating 997/1100 ...
# Generating 998/1100 ...
# Generating 999/1100 ...
# Generating 1000/1100 ...
# Generating 1001/1100 ...
# Generating 1002/1100 ...
# Generating 1003/1100 ...
# Generating 1004/1100 ...
# Generating 1005/1100 ...
# Generating 1006/1100 ...
# Generating 1007/1100 ...
# Generating 1008/1100 ...
# Generating 1009/1100 ...
# Generating 1010/1100 ...
# Generating 1011/1100 ...
# Generating 1012/1100 ...
# Generating 1013/1100 ...
# Generating 1014/1100 ...
# Generating 1015/1100 ...
# Generating 1016/1100 ...
# Generating 1017/1100 ...
# Generating 1018/1100 ...
# Generating 1019/1100 ...
# Generating 1020/1100 ...
# Generating 1021/1100 ...
# Generating 1022/1100 ...
# Generating 1023/1100 ...
# Generating 1024/1100 ...
# Generating 1025/1100 ...
# Generating 1026/1100 ...
# Generating 1027/1100 ...
# Generating 1028/1100 ...
# Generating 1029/1100 ...
# Generating 1030/1100 ...
# Generating 1031/1100 ...
# Generating 1032/1100 ...
# Generating 1033/1100 ...
# Generating 1034/1100 ...
# Generating 1035/1100 ...
# Generating 1036/1100 ...
# Generating 1037/1100 ...
# Generating 1038/1100 ...
# Generating 1039/1100 ...
# Generating 1040/1100 ...
# Generating 1041/1100 ...
# Generating 1042/1100 ...
# Generating 1043/1100 ...
# Generating 1044/1100 ...
# Generating 1045/1100 ...
# Generating 1046/1100 ...
# Generating 1047/1100 ...
# Generating 1048/1100 ...
# Generating 1049/1100 ...
# Generating 1050/1100 ...
# Generating 1051/1100 ...
# Generating 1052/1100 ...
# Generating 1053/1100 ...
# Generating 1054/1100 ...
# Generating 1055/1100 ...
# Generating 1056/1100 ...
# Generating 1057/1100 ...
# Generating 1058/1100 ...
# Generating 1059/1100 ...
# Generating 1060/1100 ...
# Generating 1061/1100 ...
# Generating 1062/1100 ...
# Generating 1063/1100 ...
# Generating 1064/1100 ...
# Generating 1065/1100 ...
# Generating 1066/1100 ...
# Generating 1067/1100 ...
# Generating 1068/1100 ...
# Generating 1069/1100 ...
# Generating 1070/1100 ...
# Generating 1071/1100 ...
# Generating 1072/1100 ...
# Generating 1073/1100 ...
# Generating 1074/1100 ...
# Generating 1075/1100 ...
# Generating 1076/1100 ...
# Generating 1077/1100 ...
# Generating 1078/1100 ...
# Generating 1079/1100 ...
# Generating 1080/1100 ...
# Generating 1081/1100 ...
# Generating 1082/1100 ...
# Generating 1083/1100 ...
# Generating 1084/1100 ...
# Generating 1085/1100 ...
# Generating 1086/1100 ...
# Generating 1087/1100 ...
# Generating 1088/1100 ...
# Generating 1089/1100 ...
# Generating 1090/1100 ...
# Generating 1091/1100 ...
# Generating 1092/1100 ...
# Generating 1093/1100 ...
# Generating 1094/1100 ...
# Generating 1095/1100 ...
# Generating 1096/1100 ...
# Generating 1097/1100 ...
# Generating 1098/1100 ...
# Generating 1099/1100 ...
