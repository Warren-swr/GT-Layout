# %%
"""
    a test script for box-shape reconstruction
"""

import os
import sys
import shutil
import numpy as np
import torch
import utils
import vis_utils_layout as vis_utils
from data_layout import LayoutDataset, Tree
import model_layout as model
from random import shuffle

sys.setrecursionlimit(5000) # this code uses recursion a lot for code simplicity

# how many shapes to evaluate (the top-K in test.txt)
num_recon = 50

path = '/home/weiran/Projects/RvNN-Layout/GT-Layout/magazine/logs/magazine_2.5K_test_emb'
cheakpoint = ''

# load train config
conf = torch.load(path + '/conf.pth')

# load object category information
Tree.load_category_info(conf.category)
conf.device = 'cuda:1'

# set up device
device = torch.device(conf.device)
print(f'Using device: {conf.device}')

# check if eval results already exist. If so, delete it. 
out_dir = path + '/recon'
if os.path.exists(out_dir):
    # response = input('result directory %s exists, overwrite? (y/n) ' % out_dir)
    # if response != 'y':
    #     sys.exit()
    shutil.rmtree(out_dir)

# create a new directory to store eval results
os.mkdir(out_dir)

# create models
# we disable probabilistic because we do not need to jitter the decoded z during inference
encoder = model.RecursiveEncoder(conf, variational=True, probabilistic=True)
decoder = model.RecursiveDecoder(conf)

# load the pretrained models
print('Loading ckpt pretrained_encoder.pth')
data_to_restore = torch.load(path + '/ckpts/' + cheakpoint + 'net_encoder.pth')
encoder.load_state_dict(data_to_restore, strict=True)
print('DONE\n')
print('Loading ckpt pretrained_decoder.pth')
data_to_restore = torch.load(path + '/ckpts/' + cheakpoint + 'net_decoder.pth')
decoder.load_state_dict(data_to_restore, strict=True)
print('DONE\n')

# send to device
encoder.to(device)
decoder.to(device)

# set models to evaluation mode
encoder.eval()
decoder.eval()

data_path = '/home/weiran/Projects/RvNN-Layout/data/magazine-ours/magazine_0417_2.5K/'

# read test.txt
with open(data_path + 'train.txt', 'r') as fin:
    data_list = [l.rstrip() for l in fin.readlines()]

# shuffle(data_list)

num_recon = 300

# reconstruct shapes
with torch.no_grad():
    for i in range(num_recon):
        print(f'Reconstructing {i} / {num_recon} ...')

        # load the gt data as the input
        obj = LayoutDataset.load_object(data_path + data_list[i] + '.json')
        obj.to(device)

        # feed through the encoder to get a code z
        # root_code = encoder.encode_structure(obj)
        root_code_and_kld = encoder.encode_structure(obj)
        root_code = root_code_and_kld[:, :conf.feature_size]

        # infer through the decoder to get the reconstructed output
        # set maximal tree depth to conf.max_tree_depth
        obj_arr = decoder.decode_structure(z=root_code, max_depth=conf.max_tree_depth)
        obj_arr.get_arrbox()

        # output the hierarchy
        with open(os.path.join(out_dir, data_list[i] + '_GT.txt'), 'w') as fout:
            fout.write(str(obj)+'\n\n')
            
        with open(os.path.join(out_dir, data_list[i] + '_PRED.txt'), 'w') as fout:
            fout.write(str(obj_arr)+'\n\n')

        # output the assembled box-shape
        vis_utils.draw_partnet_objects([obj], \
            object_names=['GT'], leafs_only=True, \
            sem_colors_filename='./part_colors_magazine.txt', figsize=(5, 6), \
            out_fn=os.path.join(out_dir, data_list[i] + '_GT.png'))
        
        vis_utils.draw_partnet_objects([obj], \
            object_names=['GT'], leafs_only=True, \
            sem_colors_filename='./part_colors_magazine.txt', figsize=(5, 6), \
            out_fn=os.path.join(out_dir, data_list[i] + '_GT.svg'))
        
        vis_utils.draw_partnet_objects([obj_arr], \
            object_names=['PRED'], leafs_only=True, \
            sem_colors_filename='./part_colors_magazine.txt', figsize=(5, 6), \
            out_fn=os.path.join(out_dir, data_list[i] + '_PRED.png'))

        vis_utils.draw_partnet_objects([obj_arr], \
            object_names=['PRED'], leafs_only=True, \
            sem_colors_filename='./part_colors_magazine.txt', figsize=(5, 6), \
            out_fn=os.path.join(out_dir, data_list[i] + '_PRED.svg'))
# Out:
# Using device: cuda:1
# Loading ckpt pretrained_encoder.pth
# DONE
#
# Loading ckpt pretrained_decoder.pth
# DONE
#
# Reconstructing 0 / 300 ...
# Reconstructing 1 / 300 ...
# Reconstructing 2 / 300 ...
# Reconstructing 3 / 300 ...
# Reconstructing 4 / 300 ...
# Reconstructing 5 / 300 ...
# Reconstructing 6 / 300 ...
# Reconstructing 7 / 300 ...
# Reconstructing 8 / 300 ...
# Reconstructing 9 / 300 ...
# Reconstructing 10 / 300 ...
# Reconstructing 11 / 300 ...
# Reconstructing 12 / 300 ...
# Reconstructing 13 / 300 ...
# Reconstructing 14 / 300 ...
# Reconstructing 15 / 300 ...
# Reconstructing 16 / 300 ...
# Reconstructing 17 / 300 ...
# Reconstructing 18 / 300 ...
# Reconstructing 19 / 300 ...
# Reconstructing 20 / 300 ...
# Reconstructing 21 / 300 ...
# Reconstructing 22 / 300 ...
# Reconstructing 23 / 300 ...
# Reconstructing 24 / 300 ...
# Reconstructing 25 / 300 ...
# Reconstructing 26 / 300 ...
# Reconstructing 27 / 300 ...
# Reconstructing 28 / 300 ...
# Reconstructing 29 / 300 ...
# Reconstructing 30 / 300 ...
# Reconstructing 31 / 300 ...
# Reconstructing 32 / 300 ...
# Reconstructing 33 / 300 ...
# Reconstructing 34 / 300 ...
# Reconstructing 35 / 300 ...
# Reconstructing 36 / 300 ...
# Reconstructing 37 / 300 ...
# Reconstructing 38 / 300 ...
# Reconstructing 39 / 300 ...
# Reconstructing 40 / 300 ...
# Reconstructing 41 / 300 ...
# Reconstructing 42 / 300 ...
# Reconstructing 43 / 300 ...
# Reconstructing 44 / 300 ...
# Reconstructing 45 / 300 ...
# Reconstructing 46 / 300 ...
# Reconstructing 47 / 300 ...
# Reconstructing 48 / 300 ...
# Reconstructing 49 / 300 ...
# Reconstructing 50 / 300 ...
# Reconstructing 51 / 300 ...
# Reconstructing 52 / 300 ...
# Reconstructing 53 / 300 ...
# Reconstructing 54 / 300 ...
# Reconstructing 55 / 300 ...
# Reconstructing 56 / 300 ...
# Reconstructing 57 / 300 ...
# Reconstructing 58 / 300 ...
# Reconstructing 59 / 300 ...
# Reconstructing 60 / 300 ...
# Reconstructing 61 / 300 ...
# Reconstructing 62 / 300 ...
# Reconstructing 63 / 300 ...
# Reconstructing 64 / 300 ...
# Reconstructing 65 / 300 ...
# Reconstructing 66 / 300 ...
# Reconstructing 67 / 300 ...
# Reconstructing 68 / 300 ...
# Reconstructing 69 / 300 ...
# Reconstructing 70 / 300 ...
# Reconstructing 71 / 300 ...
# Reconstructing 72 / 300 ...
# Reconstructing 73 / 300 ...
# Reconstructing 74 / 300 ...
# Reconstructing 75 / 300 ...
# Reconstructing 76 / 300 ...
# Reconstructing 77 / 300 ...
# Reconstructing 78 / 300 ...
# Reconstructing 79 / 300 ...
# Reconstructing 80 / 300 ...
# Reconstructing 81 / 300 ...
# Reconstructing 82 / 300 ...
# Reconstructing 83 / 300 ...
# Reconstructing 84 / 300 ...
# Reconstructing 85 / 300 ...
# Reconstructing 86 / 300 ...
# Reconstructing 87 / 300 ...
# Reconstructing 88 / 300 ...
# Reconstructing 89 / 300 ...
# Reconstructing 90 / 300 ...
# Reconstructing 91 / 300 ...
# Reconstructing 92 / 300 ...
# Reconstructing 93 / 300 ...
# Reconstructing 94 / 300 ...
# Reconstructing 95 / 300 ...
# Reconstructing 96 / 300 ...
# Reconstructing 97 / 300 ...
# Reconstructing 98 / 300 ...
# Reconstructing 99 / 300 ...
# Reconstructing 100 / 300 ...
# Reconstructing 101 / 300 ...
# Reconstructing 102 / 300 ...
# Reconstructing 103 / 300 ...
# Reconstructing 104 / 300 ...
# Reconstructing 105 / 300 ...
# Reconstructing 106 / 300 ...
# Reconstructing 107 / 300 ...
# Reconstructing 108 / 300 ...
# Reconstructing 109 / 300 ...
# Reconstructing 110 / 300 ...
# Reconstructing 111 / 300 ...
# Reconstructing 112 / 300 ...
# Reconstructing 113 / 300 ...
# Reconstructing 114 / 300 ...
# Reconstructing 115 / 300 ...
# Reconstructing 116 / 300 ...
# Reconstructing 117 / 300 ...
# Reconstructing 118 / 300 ...
# Reconstructing 119 / 300 ...
# Reconstructing 120 / 300 ...
# Reconstructing 121 / 300 ...
# Reconstructing 122 / 300 ...
# Reconstructing 123 / 300 ...
# Reconstructing 124 / 300 ...
# Reconstructing 125 / 300 ...
# Reconstructing 126 / 300 ...
# Reconstructing 127 / 300 ...
# Reconstructing 128 / 300 ...
# Reconstructing 129 / 300 ...
# Reconstructing 130 / 300 ...
# Reconstructing 131 / 300 ...
# Reconstructing 132 / 300 ...
# Reconstructing 133 / 300 ...
# Reconstructing 134 / 300 ...
# Reconstructing 135 / 300 ...
# Reconstructing 136 / 300 ...
# Reconstructing 137 / 300 ...
# Reconstructing 138 / 300 ...
# Reconstructing 139 / 300 ...
# Reconstructing 140 / 300 ...
# Reconstructing 141 / 300 ...
# Reconstructing 142 / 300 ...
# Reconstructing 143 / 300 ...
# Reconstructing 144 / 300 ...
# Reconstructing 145 / 300 ...
# Reconstructing 146 / 300 ...
# Reconstructing 147 / 300 ...
# Reconstructing 148 / 300 ...
# Reconstructing 149 / 300 ...
# Reconstructing 150 / 300 ...
# Reconstructing 151 / 300 ...
# Reconstructing 152 / 300 ...
# Reconstructing 153 / 300 ...
# Reconstructing 154 / 300 ...
# Reconstructing 155 / 300 ...
# Reconstructing 156 / 300 ...
# Reconstructing 157 / 300 ...
# Reconstructing 158 / 300 ...
# Reconstructing 159 / 300 ...
# Reconstructing 160 / 300 ...
# Reconstructing 161 / 300 ...
# Reconstructing 162 / 300 ...
# Reconstructing 163 / 300 ...
# Reconstructing 164 / 300 ...
# Reconstructing 165 / 300 ...
# Reconstructing 166 / 300 ...
# Reconstructing 167 / 300 ...
# Reconstructing 168 / 300 ...
# Reconstructing 169 / 300 ...
# Reconstructing 170 / 300 ...
# Reconstructing 171 / 300 ...
# Reconstructing 172 / 300 ...
# Reconstructing 173 / 300 ...
# Reconstructing 174 / 300 ...
# Reconstructing 175 / 300 ...
# Reconstructing 176 / 300 ...
# Reconstructing 177 / 300 ...
# Reconstructing 178 / 300 ...
# Reconstructing 179 / 300 ...
# Reconstructing 180 / 300 ...
# Reconstructing 181 / 300 ...
# Reconstructing 182 / 300 ...
# Reconstructing 183 / 300 ...
# Reconstructing 184 / 300 ...
# Reconstructing 185 / 300 ...
# Reconstructing 186 / 300 ...
# Reconstructing 187 / 300 ...
# Reconstructing 188 / 300 ...
# Reconstructing 189 / 300 ...
# Reconstructing 190 / 300 ...
# Reconstructing 191 / 300 ...
# Reconstructing 192 / 300 ...
# Reconstructing 193 / 300 ...
# Reconstructing 194 / 300 ...
# Reconstructing 195 / 300 ...
# Reconstructing 196 / 300 ...
# Reconstructing 197 / 300 ...
# Reconstructing 198 / 300 ...
# Reconstructing 199 / 300 ...
# Reconstructing 200 / 300 ...
# Reconstructing 201 / 300 ...
# Reconstructing 202 / 300 ...
# Reconstructing 203 / 300 ...
# Reconstructing 204 / 300 ...
# Reconstructing 205 / 300 ...
# Reconstructing 206 / 300 ...
# Reconstructing 207 / 300 ...
# Reconstructing 208 / 300 ...
# Reconstructing 209 / 300 ...
# Reconstructing 210 / 300 ...
# Reconstructing 211 / 300 ...
# Reconstructing 212 / 300 ...
# Reconstructing 213 / 300 ...
# Reconstructing 214 / 300 ...
# Reconstructing 215 / 300 ...
# Reconstructing 216 / 300 ...
# Reconstructing 217 / 300 ...
# Reconstructing 218 / 300 ...
# Reconstructing 219 / 300 ...
# Reconstructing 220 / 300 ...
# Reconstructing 221 / 300 ...
# Reconstructing 222 / 300 ...
# Reconstructing 223 / 300 ...
# Reconstructing 224 / 300 ...
# Reconstructing 225 / 300 ...
# Reconstructing 226 / 300 ...
# Reconstructing 227 / 300 ...
# Reconstructing 228 / 300 ...
# Reconstructing 229 / 300 ...
# Reconstructing 230 / 300 ...
# Reconstructing 231 / 300 ...
# Reconstructing 232 / 300 ...
# Reconstructing 233 / 300 ...
# Reconstructing 234 / 300 ...
# Reconstructing 235 / 300 ...
# Reconstructing 236 / 300 ...
# Reconstructing 237 / 300 ...
# Reconstructing 238 / 300 ...
# Reconstructing 239 / 300 ...
# Reconstructing 240 / 300 ...
# Reconstructing 241 / 300 ...
# Reconstructing 242 / 300 ...
# Reconstructing 243 / 300 ...
# Reconstructing 244 / 300 ...
# Reconstructing 245 / 300 ...
# Reconstructing 246 / 300 ...
# Reconstructing 247 / 300 ...
# Reconstructing 248 / 300 ...
# Reconstructing 249 / 300 ...
# Reconstructing 250 / 300 ...
# Reconstructing 251 / 300 ...
# Reconstructing 252 / 300 ...
# Reconstructing 253 / 300 ...
# Reconstructing 254 / 300 ...
# Reconstructing 255 / 300 ...
# Reconstructing 256 / 300 ...
# Reconstructing 257 / 300 ...
# Reconstructing 258 / 300 ...
# Reconstructing 259 / 300 ...
# Reconstructing 260 / 300 ...
# Reconstructing 261 / 300 ...
# Reconstructing 262 / 300 ...
# Reconstructing 263 / 300 ...
# Reconstructing 264 / 300 ...
# Reconstructing 265 / 300 ...
# Reconstructing 266 / 300 ...
# Reconstructing 267 / 300 ...
# Reconstructing 268 / 300 ...
# Reconstructing 269 / 300 ...
# Reconstructing 270 / 300 ...
# Reconstructing 271 / 300 ...
# Reconstructing 272 / 300 ...
# Reconstructing 273 / 300 ...
# Reconstructing 274 / 300 ...
# Reconstructing 275 / 300 ...
# Reconstructing 276 / 300 ...
# Reconstructing 277 / 300 ...
# Reconstructing 278 / 300 ...
# Reconstructing 279 / 300 ...
# Reconstructing 280 / 300 ...
# Reconstructing 281 / 300 ...
# Reconstructing 282 / 300 ...
# Reconstructing 283 / 300 ...
# Reconstructing 284 / 300 ...
# Reconstructing 285 / 300 ...
# Reconstructing 286 / 300 ...
# Reconstructing 287 / 300 ...
# Reconstructing 288 / 300 ...
# Reconstructing 289 / 300 ...
# Reconstructing 290 / 300 ...
# Reconstructing 291 / 300 ...
# Reconstructing 292 / 300 ...
# Reconstructing 293 / 300 ...
# Reconstructing 294 / 300 ...
# Reconstructing 295 / 300 ...
# Reconstructing 296 / 300 ...
# Reconstructing 297 / 300 ...
# Reconstructing 298 / 300 ...
# Reconstructing 299 / 300 ...
